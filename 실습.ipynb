# %% [markdown]
# <a href="https://colab.research.google.com/github/SEONGJUN-HAN/edu/blob/main/%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
url = 'https://github.com/SEONGJUN-HAN/edu/blob/main/2024.10.16..xlsx?raw=true'
# data = [[10, float('nan'), 50], [20, 20, 80], [30, 40 ,80], [40, 60, 20]]
df = pd.read_excel(url)
df
# Out:
#           사업관리카드(현액)       Unnamed: 1       Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0                NaN              NaN              NaN        NaN         NaN
# 1               세부사업             세부항목           원가통계비목       산출내역         예산액
# 2            교직원역량강화             직무연수            일반수용비   자체_직무연수비     1950000
# 3            교직원역량강화             직무연수  [ 세 부 항 목 소 계 ]        NaN     1950000
# 4            교직원역량강화          교직원 워크샵            일반수용비     자체_대관비      700000
# ..               ...              ...              ...        ...         ...
# 557         행정지원인력운용     행정(사무)실무사인건비  [ 세 부 항 목 소 계 ]        NaN      480000
# 558         행정지원인력운용  [ 세 부 사 업 소 계 ]              NaN        NaN      480000
# 559  [ 단 위 사 업 합 계 ]              NaN              NaN        NaN    61798000
# 560  [ 정 책 사 업 합 계 ]              NaN              NaN        NaN   309281000
# 561     [ 총      계 ]              NaN              NaN        NaN  2340116000
#
# ...

# %%
# df['tip'].astype('float')
df['tip'] = pd.to_numeric(df['tip'],errors='coerce')
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99   NaN  Female     No   Sun   Lunch     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male    NaN   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    NaN   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female    NaN  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['time'] = df['time'].replace({'Lunch':0, 'Dinner':1})
# Out:
# <ipython-input-121-8fb4c7af894c>:1: FutureWarning:
#
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
df['smoker'].fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-9930b2b39c53> in <cell line: 1>()
# ----> 1 df['smoker'].fillna()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7291                     )
#    7292
# -> 7293         value, method = validate_fillna_kwargs(value, method)
#    7294         if method is not None:
#    7295             warnings.warn(
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_validators.py in validate_fillna_kwargs(value, method, validate_scalar_dict_value)
#     291
#     292     if value is None and method is None:
# --> 293         raise ValueError("Must specify a fill 'value' or 'method'.")
#     294     if value is None and method is not None:
#     295         method = clean_fill_method(method)
#
# ...
